# %%
#Import dependencies and setup citipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats=np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs=np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates=list(lat_lngs)

# %%
#Create a list for holding the cities
cities=[]
#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)
#Print the city count
len(cities)
# Out:
# 764

# %%
#Perform an API call with the OpenWeatherMap
#Import requests library
import requests
#Import the API key
from config import weather_api_key

# %%
#Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data=[]

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count=1
set_count=1

#Loop through all cities in the list
for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes
    if (i % 50==0 and i >= 50):
        set_count += 1
        record_count =1
    #Create enpoint URL with each city
    city_url=url+"&q="+city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count +=1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | shahr-e babak
# Processing Record 3 of Set 1 | dion
# Processing Record 4 of Set 1 | margate
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | lerwick
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | coihaique
# Processing Record 11 of Set 1 | nome
# Processing Record 12 of Set 1 | vieste
# Processing Record 13 of Set 1 | grand gaube
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | zeya
# Processing Record 17 of Set 1 | belyy yar
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | volosovo
# Processing Record 20 of Set 1 | palasa
# Processing Record 21 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | umba
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | crossville
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | dubovka
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | wyndham
# Processing Record 33 of Set 1 | paamiut
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | nishihara
# Processing Record 36 of Set 1 | beloha
# Processing Record 37 of Set 1 | rocha
# Processing Record 38 of Set 1 | port hardy
# Processing Record 39 of Set 1 | meix-devant-virton
# Processing Record 40 of Set 1 | fort-shevchenko
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | yulara
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | waingapu
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | takoradi
# Processing Record 48 of Set 1 | eydhafushi
# Processing Record 49 of Set 1 | calatayud
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | nanakuli
# Processing Record 4 of Set 2 | yangjiang
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | muros
# Processing Record 7 of Set 2 | kyren
# Processing Record 8 of Set 2 | farafangana
# Processing Record 9 of Set 2 | victoria
# Processing Record 10 of Set 2 | faanui
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | alta floresta
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | valparaiso
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | tari
# Processing Record 17 of Set 2 | itainopolis
# Processing Record 18 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 2 | oyama
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | dargaville
# Processing Record 24 of Set 2 | hasaki
# Processing Record 25 of Set 2 | sitka
# Processing Record 26 of Set 2 | linxia
# Processing Record 27 of Set 2 | katsuura
# Processing Record 28 of Set 2 | churapcha
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | rochegda
# Processing Record 31 of Set 2 | fortuna
# Processing Record 32 of Set 2 | mozarlandia
# Processing Record 33 of Set 2 | perth
# Processing Record 34 of Set 2 | santa rosa
# Processing Record 35 of Set 2 | lakatoro
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 2 | severo-kurilsk
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | jalu
# Processing Record 41 of Set 2 | balimo
# City not found. Skipping...
# Processing Record 42 of Set 2 | dunedin
# Processing Record 43 of Set 2 | nanortalik
# Processing Record 44 of Set 2 | tucuma
# Processing Record 45 of Set 2 | provideniya
# Processing Record 46 of Set 2 | acarau
# Processing Record 47 of Set 2 | padang
# Processing Record 48 of Set 2 | plaridel
# Processing Record 49 of Set 2 | bambous virieux
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | huarmey
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | la uribe
# City not found. Skipping...
# Processing Record 4 of Set 3 | george
# Processing Record 5 of Set 3 | ponta do sol
# Processing Record 6 of Set 3 | togur
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | coahuayana
# Processing Record 9 of Set 3 | dauphin
# Processing Record 10 of Set 3 | jieshi
# Processing Record 11 of Set 3 | muisne
# Processing Record 12 of Set 3 | lavrentiya
# Processing Record 13 of Set 3 | aketi
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | moissala
# Processing Record 16 of Set 3 | ballitoville
# Processing Record 17 of Set 3 | doba
# Processing Record 18 of Set 3 | vao
# Processing Record 19 of Set 3 | bayan
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | yeppoon
# Processing Record 22 of Set 3 | pontianak
# Processing Record 23 of Set 3 | paracatu
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | naze
# Processing Record 26 of Set 3 | oistins
# Processing Record 27 of Set 3 | ballina
# Processing Record 28 of Set 3 | surt
# Processing Record 29 of Set 3 | jurm
# Processing Record 30 of Set 3 | flin flon
# Processing Record 31 of Set 3 | narsaq
# Processing Record 32 of Set 3 | waipawa
# Processing Record 33 of Set 3 | simoes
# Processing Record 34 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 3 | mayumba
# Processing Record 36 of Set 3 | lahaina
# Processing Record 37 of Set 3 | necochea
# Processing Record 38 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 3 | tamandare
# Processing Record 40 of Set 3 | santa isabel do rio negro
# Processing Record 41 of Set 3 | fort dodge
# Processing Record 42 of Set 3 | harlingen
# Processing Record 43 of Set 3 | zhicheng
# Processing Record 44 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 3 | plettenberg bay
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | abrau-dyurso
# Processing Record 48 of Set 3 | biak
# Processing Record 49 of Set 3 | sibu
# Processing Record 50 of Set 3 | qaanaaq
# Processing Record 1 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 4 | longyearbyen
# Processing Record 3 of Set 4 | ulaangom
# Processing Record 4 of Set 4 | palm beach
# Processing Record 5 of Set 4 | forbes
# Processing Record 6 of Set 4 | vestmannaeyjar
# Processing Record 7 of Set 4 | bartoszyce
# Processing Record 8 of Set 4 | liberty
# Processing Record 9 of Set 4 | lynn haven
# Processing Record 10 of Set 4 | trat
# Processing Record 11 of Set 4 | saint-pierre
# Processing Record 12 of Set 4 | kasongo-lunda
# Processing Record 13 of Set 4 | mitu
# Processing Record 14 of Set 4 | yatou
# Processing Record 15 of Set 4 | mahebourg
# Processing Record 16 of Set 4 | canela
# Processing Record 17 of Set 4 | collierville
# Processing Record 18 of Set 4 | talnakh
# Processing Record 19 of Set 4 | isla vista
# Processing Record 20 of Set 4 | mehamn
# Processing Record 21 of Set 4 | pervomayskoye
# Processing Record 22 of Set 4 | praia da vitoria
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | knysna
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | souillac
# Processing Record 27 of Set 4 | nyurba
# Processing Record 28 of Set 4 | deer lake
# Processing Record 29 of Set 4 | itarema
# Processing Record 30 of Set 4 | new norfolk
# Processing Record 31 of Set 4 | iquique
# Processing Record 32 of Set 4 | sheridan
# Processing Record 33 of Set 4 | alakurtti
# Processing Record 34 of Set 4 | milton
# Processing Record 35 of Set 4 | lakes entrance
# Processing Record 36 of Set 4 | oneida
# Processing Record 37 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 4 | mayo
# Processing Record 40 of Set 4 | biloela
# Processing Record 41 of Set 4 | camana
# Processing Record 42 of Set 4 | pisco
# Processing Record 43 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 4 | san pedro
# Processing Record 45 of Set 4 | calvinia
# Processing Record 46 of Set 4 | vardo
# Processing Record 47 of Set 4 | lewistown
# Processing Record 48 of Set 4 | uncia
# Processing Record 49 of Set 4 | cheney
# Processing Record 50 of Set 4 | shingu
# Processing Record 1 of Set 5 | youghal
# Processing Record 2 of Set 5 | mastic beach
# Processing Record 3 of Set 5 | la rioja
# Processing Record 4 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 5 | lethem
# Processing Record 6 of Set 5 | lithakia
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 5 | maniitsoq
# Processing Record 10 of Set 5 | touros
# Processing Record 11 of Set 5 | ostrovnoy
# Processing Record 12 of Set 5 | moiyabana
# City not found. Skipping...
# Processing Record 13 of Set 5 | coquimbo
# Processing Record 14 of Set 5 | nikolskoye
# Processing Record 15 of Set 5 | cherskiy
# Processing Record 16 of Set 5 | rawson
# Processing Record 17 of Set 5 | codrington
# Processing Record 18 of Set 5 | tudela
# Processing Record 19 of Set 5 | lompoc
# Processing Record 20 of Set 5 | graaff-reinet
# Processing Record 21 of Set 5 | georgetown
# Processing Record 22 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 5 | geraldton
# Processing Record 24 of Set 5 | hayden
# Processing Record 25 of Set 5 | chernyshevskiy
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | dire dawa
# Processing Record 28 of Set 5 | zhuanghe
# Processing Record 29 of Set 5 | ferrol
# Processing Record 30 of Set 5 | qurunbaliyah
# City not found. Skipping...
# Processing Record 31 of Set 5 | manokwari
# Processing Record 32 of Set 5 | luchingu
# Processing Record 33 of Set 5 | upernavik
# Processing Record 34 of Set 5 | minsk
# Processing Record 35 of Set 5 | nouadhibou
# Processing Record 36 of Set 5 | ballymena
# Processing Record 37 of Set 5 | olinda
# Processing Record 38 of Set 5 | salinas
# Processing Record 39 of Set 5 | sobolevo
# Processing Record 40 of Set 5 | broome
# Processing Record 41 of Set 5 | norman wells
# Processing Record 42 of Set 5 | qiongshan
# Processing Record 43 of Set 5 | kaeo
# Processing Record 44 of Set 5 | kangaatsiaq
# Processing Record 45 of Set 5 | yarkovo
# Processing Record 46 of Set 5 | mushie
# Processing Record 47 of Set 5 | wawa
# Processing Record 48 of Set 5 | ugoofaaru
# Processing Record 49 of Set 5 | tuatapere
# Processing Record 50 of Set 5 | ajdabiya
# Processing Record 1 of Set 6 | hobyo
# Processing Record 2 of Set 6 | kruisfontein
# Processing Record 3 of Set 6 | luderitz
# Processing Record 4 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 6 | bengkulu
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | los llanos de aridane
# Processing Record 8 of Set 6 | saskylakh
# Processing Record 9 of Set 6 | gao
# Processing Record 10 of Set 6 | faya
# Processing Record 11 of Set 6 | mirpur mathelo
# Processing Record 12 of Set 6 | bandarbeyla
# Processing Record 13 of Set 6 | kaitangata
# Processing Record 14 of Set 6 | cabo san lucas
# Processing Record 15 of Set 6 | betioky
# Processing Record 16 of Set 6 | sur
# Processing Record 17 of Set 6 | nadezhda
# Processing Record 18 of Set 6 | kloulklubed
# Processing Record 19 of Set 6 | san quintin
# Processing Record 20 of Set 6 | ambunti
# Processing Record 21 of Set 6 | veraval
# Processing Record 22 of Set 6 | miraflores
# Processing Record 23 of Set 6 | hamilton
# Processing Record 24 of Set 6 | magna
# Processing Record 25 of Set 6 | tupik
# Processing Record 26 of Set 6 | puerto leguizamo
# Processing Record 27 of Set 6 | avera
# Processing Record 28 of Set 6 | oga
# Processing Record 29 of Set 6 | karpathos
# Processing Record 30 of Set 6 | benito juarez
# Processing Record 31 of Set 6 | chokurdakh
# Processing Record 32 of Set 6 | victor harbor
# Processing Record 33 of Set 6 | bubaque
# Processing Record 34 of Set 6 | atar
# Processing Record 35 of Set 6 | carmelo
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 | berlevag
# Processing Record 38 of Set 6 | catamarca
# Processing Record 39 of Set 6 | sao filipe
# Processing Record 40 of Set 6 | machaneng
# Processing Record 41 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 42 of Set 6 | carnarvon
# Processing Record 43 of Set 6 | port moresby
# Processing Record 44 of Set 6 | wanlaweyn
# Processing Record 45 of Set 6 | sri aman
# Processing Record 46 of Set 6 | bilma
# Processing Record 47 of Set 6 | tasiilaq
# Processing Record 48 of Set 6 | sao felix do xingu
# Processing Record 49 of Set 6 | ciudad bolivar
# Processing Record 50 of Set 6 | goderich
# Processing Record 1 of Set 7 | sakaiminato
# Processing Record 2 of Set 7 | ariquemes
# Processing Record 3 of Set 7 | kavieng
# Processing Record 4 of Set 7 | loukhi
# Processing Record 5 of Set 7 | sao jose do rio pardo
# Processing Record 6 of Set 7 | maningrida
# Processing Record 7 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 7 | lang suan
# Processing Record 9 of Set 7 | cessnock
# Processing Record 10 of Set 7 | marawi
# Processing Record 11 of Set 7 | lasa
# Processing Record 12 of Set 7 | changping
# Processing Record 13 of Set 7 | aklavik
# Processing Record 14 of Set 7 | bellevue
# Processing Record 15 of Set 7 | inhambane
# Processing Record 16 of Set 7 | miranpur
# Processing Record 17 of Set 7 | whitehorse
# Processing Record 18 of Set 7 | atbasar
# Processing Record 19 of Set 7 | palmer
# Processing Record 20 of Set 7 | sorong
# Processing Record 21 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 7 | kerrobert
# Processing Record 23 of Set 7 | koumac
# Processing Record 24 of Set 7 | mount isa
# Processing Record 25 of Set 7 | vila velha
# Processing Record 26 of Set 7 | dingle
# Processing Record 27 of Set 7 | tilichiki
# Processing Record 28 of Set 7 | saldanha
# Processing Record 29 of Set 7 | raudeberg
# Processing Record 30 of Set 7 | bocas del toro
# Processing Record 31 of Set 7 | cairns
# Processing Record 32 of Set 7 | mormugao
# Processing Record 33 of Set 7 | tarrega
# Processing Record 34 of Set 7 | skovorodino
# Processing Record 35 of Set 7 | isabela
# Processing Record 36 of Set 7 | den helder
# Processing Record 37 of Set 7 | neiafu
# Processing Record 38 of Set 7 | college
# Processing Record 39 of Set 7 | korla
# Processing Record 40 of Set 7 | sindor
# Processing Record 41 of Set 7 | la ronge
# Processing Record 42 of Set 7 | icod de los vinos
# Processing Record 43 of Set 7 | onda
# Processing Record 44 of Set 7 | cascais
# Processing Record 45 of Set 7 | jimo
# Processing Record 46 of Set 7 | tucuman
# Processing Record 47 of Set 7 | melilla
# Processing Record 48 of Set 7 | port lincoln
# Processing Record 49 of Set 7 | laguna
# Processing Record 50 of Set 7 | half moon bay
# Processing Record 1 of Set 8 | shache
# Processing Record 2 of Set 8 | doha
# Processing Record 3 of Set 8 | vigrestad
# Processing Record 4 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 8 | broken hill
# Processing Record 6 of Set 8 | enid
# Processing Record 7 of Set 8 | ocos
# Processing Record 8 of Set 8 | tamasi
# Processing Record 9 of Set 8 | shakiso
# Processing Record 10 of Set 8 | linjiang
# Processing Record 11 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 12 of Set 8 | tiksi
# Processing Record 13 of Set 8 | mineiros
# Processing Record 14 of Set 8 | verkhovazhye
# Processing Record 15 of Set 8 | torbay
# Processing Record 16 of Set 8 | ossora
# Processing Record 17 of Set 8 | oranjestad
# Processing Record 18 of Set 8 | ipixuna
# Processing Record 19 of Set 8 | khatanga
# Processing Record 20 of Set 8 | tyrma
# Processing Record 21 of Set 8 | saint-augustin
# Processing Record 22 of Set 8 | salisbury
# Processing Record 23 of Set 8 | alanya
# Processing Record 24 of Set 8 | great yarmouth
# Processing Record 25 of Set 8 | ozernovskiy
# Processing Record 26 of Set 8 | lander
# Processing Record 27 of Set 8 | apatity
# Processing Record 28 of Set 8 | qeshm
# Processing Record 29 of Set 8 | tura
# Processing Record 30 of Set 8 | valenca
# Processing Record 31 of Set 8 | guerrero negro
# Processing Record 32 of Set 8 | kaiyuan
# Processing Record 33 of Set 8 | bathsheba
# Processing Record 34 of Set 8 | barranca
# Processing Record 35 of Set 8 | ambilobe
# Processing Record 36 of Set 8 | aksarka
# Processing Record 37 of Set 8 | clyde river
# Processing Record 38 of Set 8 | chippewa falls
# Processing Record 39 of Set 8 | non sung
# Processing Record 40 of Set 8 | novouzensk
# Processing Record 41 of Set 8 | isangel
# Processing Record 42 of Set 8 | adrar
# Processing Record 43 of Set 8 | cururupu
# Processing Record 44 of Set 8 | vitim
# Processing Record 45 of Set 8 | abha
# Processing Record 46 of Set 8 | zaragoza
# Processing Record 47 of Set 8 | novikovo
# Processing Record 48 of Set 8 | parambu
# Processing Record 49 of Set 8 | braintree
# Processing Record 50 of Set 8 | chalus
# Processing Record 1 of Set 9 | asheboro
# Processing Record 2 of Set 9 | peniche
# Processing Record 3 of Set 9 | gawler
# Processing Record 4 of Set 9 | kriel
# Processing Record 5 of Set 9 | ketchikan
# Processing Record 6 of Set 9 | sakakah
# Processing Record 7 of Set 9 | arrifes
# Processing Record 8 of Set 9 | te anau
# Processing Record 9 of Set 9 | alofi
# Processing Record 10 of Set 9 | goundi
# Processing Record 11 of Set 9 | kitob
# Processing Record 12 of Set 9 | buchanan
# Processing Record 13 of Set 9 | haukipudas
# Processing Record 14 of Set 9 | eureka
# Processing Record 15 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 16 of Set 9 | arzgir
# Processing Record 17 of Set 9 | gat
# Processing Record 18 of Set 9 | aljezur
# Processing Record 19 of Set 9 | villazon
# Processing Record 20 of Set 9 | vestmanna
# Processing Record 21 of Set 9 | murdochville
# Processing Record 22 of Set 9 | matara
# Processing Record 23 of Set 9 | kefamenanu
# Processing Record 24 of Set 9 | komsomolskiy
# Processing Record 25 of Set 9 | plaster rock
# Processing Record 26 of Set 9 | maun
# Processing Record 27 of Set 9 | northam
# Processing Record 28 of Set 9 | qibili
# City not found. Skipping...
# Processing Record 29 of Set 9 | hay river
# Processing Record 30 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 9 | olafsvik
# Processing Record 32 of Set 9 | kungurtug
# Processing Record 33 of Set 9 | chapais
# Processing Record 34 of Set 9 | port-gentil
# Processing Record 35 of Set 9 | ouadda
# Processing Record 36 of Set 9 | ahipara
# Processing Record 37 of Set 9 | palestine
# Processing Record 38 of Set 9 | heishan
# Processing Record 39 of Set 9 | marsh harbour
# Processing Record 40 of Set 9 | verkhnyaya toyma
# Processing Record 41 of Set 9 | tshane
# Processing Record 42 of Set 9 | kushmurun
# Processing Record 43 of Set 9 | talara
# Processing Record 44 of Set 9 | konstantinovka
# Processing Record 45 of Set 9 | caravelas
# Processing Record 46 of Set 9 | obo
# Processing Record 47 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 48 of Set 9 | humaita
# Processing Record 49 of Set 9 | atherton
# Processing Record 50 of Set 9 | svetlogorsk
# Processing Record 1 of Set 10 | sangar
# Processing Record 2 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 10 | evanston
# Processing Record 4 of Set 10 | roald
# Processing Record 5 of Set 10 | saint-joseph
# Processing Record 6 of Set 10 | akdepe
# Processing Record 7 of Set 10 | champerico
# Processing Record 8 of Set 10 | kpandae
# Processing Record 9 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 10 | ambulu
# Processing Record 11 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 10 | port hedland
# Processing Record 13 of Set 10 | pishin
# Processing Record 14 of Set 10 | nabire
# Processing Record 15 of Set 10 | fasa
# Processing Record 16 of Set 10 | banda aceh
# Processing Record 17 of Set 10 | sorland
# Processing Record 18 of Set 10 | yar-sale
# Processing Record 19 of Set 10 | latung
# Processing Record 20 of Set 10 | prainha
# Processing Record 21 of Set 10 | grindavik
# Processing Record 22 of Set 10 | warmbad
# Processing Record 23 of Set 10 | waddan
# Processing Record 24 of Set 10 | snezhnogorsk
# Processing Record 25 of Set 10 | berdigestyakh
# Processing Record 26 of Set 10 | kananga
# Processing Record 27 of Set 10 | rio grande
# Processing Record 28 of Set 10 | cabedelo
# Processing Record 29 of Set 10 | nuuk
# Processing Record 30 of Set 10 | karratha
# Processing Record 31 of Set 10 | panaba
# Processing Record 32 of Set 10 | tigil
# Processing Record 33 of Set 10 | handwara
# City not found. Skipping...
# Processing Record 34 of Set 10 | jiamusi
# Processing Record 35 of Set 10 | istok
# Processing Record 36 of Set 10 | port hawkesbury
# Processing Record 37 of Set 10 | kavaratti
# Processing Record 38 of Set 10 | duyun
# Processing Record 39 of Set 10 | kiruna
# Processing Record 40 of Set 10 | poum
# Processing Record 41 of Set 10 | hua hin
# Processing Record 42 of Set 10 | krasnoselkup
# Processing Record 43 of Set 10 | mount gambier
# Processing Record 44 of Set 10 | khairagarh
# Processing Record 45 of Set 10 | araouane
# Processing Record 46 of Set 10 | am timan
# Processing Record 47 of Set 10 | saint george
# Processing Record 48 of Set 10 | tepalcatepec
# Processing Record 49 of Set 10 | pacific grove
# Processing Record 50 of Set 10 | bonthe
# Processing Record 1 of Set 11 | guanica
# Processing Record 2 of Set 11 | menongue
# Processing Record 3 of Set 11 | okhotsk
# Processing Record 4 of Set 11 | at-bashi
# Processing Record 5 of Set 11 | san patricio
# Processing Record 6 of Set 11 | owando
# Processing Record 7 of Set 11 | lorengau
# Processing Record 8 of Set 11 | baghdad
# Processing Record 9 of Set 11 | cap malheureux
# Processing Record 10 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 11 | nargana
# Processing Record 12 of Set 11 | beringovskiy
# Processing Record 13 of Set 11 | nanhai
# Processing Record 14 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 15 of Set 11 | havre-saint-pierre
# Processing Record 16 of Set 11 | terrasini
# Processing Record 17 of Set 11 | tefe
# Processing Record 18 of Set 11 | kuito
# Processing Record 19 of Set 11 | svetlaya
# Processing Record 20 of Set 11 | manicore
# Processing Record 21 of Set 11 | skibbereen
# Processing Record 22 of Set 11 | maragogi
# Processing Record 23 of Set 11 | arlit
# Processing Record 24 of Set 11 | tocopilla
# Processing Record 25 of Set 11 | saint-georges
# Processing Record 26 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 11 | raga
# Processing Record 28 of Set 11 | ancud
# Processing Record 29 of Set 11 | vila do maio
# Processing Record 30 of Set 11 | churumuco
# City not found. Skipping...
# Processing Record 31 of Set 11 | jianhu
# Processing Record 32 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 11 | manggar
# Processing Record 34 of Set 11 | hervey bay
# Processing Record 35 of Set 11 | barhi
# Processing Record 36 of Set 11 | zaria
# Processing Record 37 of Set 11 | port maria
# Processing Record 38 of Set 11 | almaznyy
# Processing Record 39 of Set 11 | candolim
# Processing Record 40 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 11 | egvekinot
# Processing Record 42 of Set 11 | bereda
# Processing Record 43 of Set 11 | selenduma
# Processing Record 44 of Set 11 | smithers
# Processing Record 45 of Set 11 | rafai
# Processing Record 46 of Set 11 | bogale
# Processing Record 47 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 48 of Set 11 | calderitas
# Processing Record 49 of Set 11 | mwanza
# Processing Record 50 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 12 | nybro
# Processing Record 2 of Set 12 | leningradskiy
# Processing Record 3 of Set 12 | hirara
# Processing Record 4 of Set 12 | labuhan
# Processing Record 5 of Set 12 | wanxian
# Processing Record 6 of Set 12 | pochutla
# Processing Record 7 of Set 12 | yuci
# Processing Record 8 of Set 12 | kualakapuas
# Processing Record 9 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 10 of Set 12 | saposoa
# Processing Record 11 of Set 12 | flinders
# Processing Record 12 of Set 12 | buraydah
# Processing Record 13 of Set 12 | sairang
# Processing Record 14 of Set 12 | tuy hoa
# Processing Record 15 of Set 12 | saint-alexandre
# Processing Record 16 of Set 12 | cidreira
# Processing Record 17 of Set 12 | sao joao da barra
# Processing Record 18 of Set 12 | airai
# Processing Record 19 of Set 12 | kuruman
# Processing Record 20 of Set 12 | shimoda
# Processing Record 21 of Set 12 | cabra
# Processing Record 22 of Set 12 | logrono
# Processing Record 23 of Set 12 | nova olimpia
# Processing Record 24 of Set 12 | manoel urbano
# Processing Record 25 of Set 12 | sinnamary
# Processing Record 26 of Set 12 | pakxan
# Processing Record 27 of Set 12 | asau
# Processing Record 28 of Set 12 | mantua
# Processing Record 29 of Set 12 | batagay
# Processing Record 30 of Set 12 | trairi
# Processing Record 31 of Set 12 | ishigaki
# Processing Record 32 of Set 12 | lata
# Processing Record 33 of Set 12 | filadelfia
# Processing Record 34 of Set 12 | bairiki
# Processing Record 35 of Set 12 | valdivia
# Processing Record 36 of Set 12 | bokoro
# Processing Record 37 of Set 12 | upata
# Processing Record 38 of Set 12 | pingzhuang
# Processing Record 39 of Set 12 | pemba
# Processing Record 40 of Set 12 | sturgeon falls
# Processing Record 41 of Set 12 | urucui
# Processing Record 42 of Set 12 | tarut
# Processing Record 43 of Set 12 | jimeta
# Processing Record 44 of Set 12 | devonport
# Processing Record 45 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 12 | olds
# Processing Record 47 of Set 12 | zhezkazgan
# Processing Record 48 of Set 12 | arauco
# Processing Record 49 of Set 12 | tianpeng
# Processing Record 50 of Set 12 | lipari
# Processing Record 1 of Set 13 | zambezi
# Processing Record 2 of Set 13 | tuskegee
# Processing Record 3 of Set 13 | ulladulla
# Processing Record 4 of Set 13 | ust-nera
# Processing Record 5 of Set 13 | mancio lima
# Processing Record 6 of Set 13 | nong chik
# Processing Record 7 of Set 13 | pandan
# Processing Record 8 of Set 13 | juarez
# Processing Record 9 of Set 13 | wakkanai
# Processing Record 10 of Set 13 | kapuskasing
# Processing Record 11 of Set 13 | meadow lake
# Processing Record 12 of Set 13 | innisfail
# Processing Record 13 of Set 13 | prachuap khiri khan
# Processing Record 14 of Set 13 | puerto el triunfo
# Processing Record 15 of Set 13 | nantucket
# Processing Record 16 of Set 13 | alvorada
# Processing Record 17 of Set 13 | straumen
# Processing Record 18 of Set 13 | pastavy
# Processing Record 19 of Set 13 | morondava
# Processing Record 20 of Set 13 | nemuro
# Processing Record 21 of Set 13 | cruzilia
# Processing Record 22 of Set 13 | paita
# Processing Record 23 of Set 13 | chicama
# Processing Record 24 of Set 13 | smiths falls
# Processing Record 25 of Set 13 | alexandria
# Processing Record 26 of Set 13 | gagra
# Processing Record 27 of Set 13 | zunyi
# Processing Record 28 of Set 13 | ninghai
# Processing Record 29 of Set 13 | talcahuano
# Processing Record 30 of Set 13 | cabulay
# Processing Record 31 of Set 13 | daeni
# Processing Record 32 of Set 13 | carutapera
# Processing Record 33 of Set 13 | mazatan
# Processing Record 34 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 13 | dakar
# Processing Record 36 of Set 13 | lagoa
# Processing Record 37 of Set 13 | teya
# Processing Record 38 of Set 13 | henties bay
# Processing Record 39 of Set 13 | krutinka
# Processing Record 40 of Set 13 | antofagasta
# Processing Record 41 of Set 13 | linay
# Processing Record 42 of Set 13 | katobu
# Processing Record 43 of Set 13 | praya
# Processing Record 44 of Set 13 | comodoro rivadavia
# Processing Record 45 of Set 13 | sept-iles
# Processing Record 46 of Set 13 | kailua
# Processing Record 47 of Set 13 | gonbad-e qabus
# Processing Record 48 of Set 13 | scalloway
# City not found. Skipping...
# Processing Record 49 of Set 13 | vallenar
# Processing Record 50 of Set 13 | harper
# Processing Record 1 of Set 14 | boa vista
# Processing Record 2 of Set 14 | basco
# Processing Record 3 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 4 of Set 14 | beyneu
# Processing Record 5 of Set 14 | salalah
# Processing Record 6 of Set 14 | kalevala
# Processing Record 7 of Set 14 | ostersund
# Processing Record 8 of Set 14 | kununurra
# Processing Record 9 of Set 14 | snasa
# Processing Record 10 of Set 14 | kuytun
# Processing Record 11 of Set 14 | kambove
# Processing Record 12 of Set 14 | tautira
# Processing Record 13 of Set 14 | meulaboh
# Processing Record 14 of Set 14 | katherine
# Processing Record 15 of Set 14 | belmonte
# Processing Record 16 of Set 14 | galle
# Processing Record 17 of Set 14 | soyo
# Processing Record 18 of Set 14 | port blair
# Processing Record 19 of Set 14 | soe
# Processing Record 20 of Set 14 | sao joao do paraiso
# Processing Record 21 of Set 14 | aranos
# Processing Record 22 of Set 14 | kulpahar
# Processing Record 23 of Set 14 | we
# City not found. Skipping...
# Processing Record 24 of Set 14 | anadyr
# Processing Record 25 of Set 14 | toulepleu
# City not found. Skipping...
# Processing Record 26 of Set 14 | pangnirtung
# Processing Record 27 of Set 14 | shenzhen
# Processing Record 28 of Set 14 | pirenopolis
# Processing Record 29 of Set 14 | winnemucca
# Processing Record 30 of Set 14 | powell river
# Processing Record 31 of Set 14 | pimentel
# Processing Record 32 of Set 14 | sidi ali
# Processing Record 33 of Set 14 | linhares
# Processing Record 34 of Set 14 | springfield
# Processing Record 35 of Set 14 | howard springs
# Processing Record 36 of Set 14 | elizabeth city
# Processing Record 37 of Set 14 | arvika
# Processing Record 38 of Set 14 | sembe
# Processing Record 39 of Set 14 | baie-comeau
# Processing Record 40 of Set 14 | moyo
# Processing Record 41 of Set 14 | norrtalje
# Processing Record 42 of Set 14 | luau
# Processing Record 43 of Set 14 | port keats
# Processing Record 44 of Set 14 | mikhaylovka
# Processing Record 45 of Set 14 | tottori
# Processing Record 46 of Set 14 | oyon
# Processing Record 47 of Set 14 | okato
# Processing Record 48 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 14 | la ciotat
# Processing Record 50 of Set 14 | aginskoye
# Processing Record 1 of Set 15 | baykit
# Processing Record 2 of Set 15 | mascote
# Processing Record 3 of Set 15 | charters towers
# Processing Record 4 of Set 15 | quthing
# Processing Record 5 of Set 15 | kasama
# Processing Record 6 of Set 15 | sargodha
# Processing Record 7 of Set 15 | gobabis
# Processing Record 8 of Set 15 | palmas
# Processing Record 9 of Set 15 | hambantota
# Processing Record 10 of Set 15 | san jeronimo
# Processing Record 11 of Set 15 | caborca
# Processing Record 12 of Set 15 | hakodate
# Processing Record 13 of Set 15 | vostok
# Processing Record 14 of Set 15 | minot
# Processing Record 15 of Set 15 | tarko-sale
# Processing Record 16 of Set 15 | minab
# Processing Record 17 of Set 15 | venado tuerto
# Processing Record 18 of Set 15 | san carlos de bariloche
# Processing Record 19 of Set 15 | tangwani
# Processing Record 20 of Set 15 | fjerritslev
# Processing Record 21 of Set 15 | loikaw
# Processing Record 22 of Set 15 | fairbanks
# Processing Record 23 of Set 15 | shush
# Processing Record 24 of Set 15 | bowen
# Processing Record 25 of Set 15 | severo-yeniseyskiy
# Processing Record 26 of Set 15 | teguise
# Processing Record 27 of Set 15 | santa cruz de tenerife
# Processing Record 28 of Set 15 | westerly
# Processing Record 29 of Set 15 | wageningen
# Processing Record 30 of Set 15 | panguipulli
# Processing Record 31 of Set 15 | metro
# Processing Record 32 of Set 15 | copiapo
# Processing Record 33 of Set 15 | taoudenni
# Processing Record 34 of Set 15 | taltal
# Processing Record 35 of Set 15 | malkangiri
# Processing Record 36 of Set 15 | marsa matruh
# Processing Record 37 of Set 15 | dubbo
# Processing Record 38 of Set 15 | moerai
# Processing Record 39 of Set 15 | sawtell
# Processing Record 40 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 15 | sarkand
# Processing Record 42 of Set 15 | sechura
# Processing Record 43 of Set 15 | tacuarembo
# Processing Record 44 of Set 15 | ranfurly
# Processing Record 45 of Set 15 | qandala
# Processing Record 46 of Set 15 | umm kaddadah
# Processing Record 47 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 48 of Set 15 | formosa
# Processing Record 49 of Set 15 | barillas
# Processing Record 50 of Set 15 | srivardhan
# Processing Record 1 of Set 16 | kismayo
# Processing Record 2 of Set 16 | arman
# Processing Record 3 of Set 16 | kuusamo
# Processing Record 4 of Set 16 | pamanukan
# Processing Record 5 of Set 16 | alice springs
# Processing Record 6 of Set 16 | farsund
# Processing Record 7 of Set 16 | kodinar
# Processing Record 8 of Set 16 | kirakira
# Processing Record 9 of Set 16 | tombouctou
# Processing Record 10 of Set 16 | willowmore
# Processing Record 11 of Set 16 | bud
# Processing Record 12 of Set 16 | cockburn town
# Processing Record 13 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 16 | xinmin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a pandas dataframe
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Yellowknife  62.4560 -114.3525     43.41        83          40
# 1  Shahr-E Babak  30.1165   55.1186     57.56        26           1
# 2           Dion  40.1733   22.4867     66.76        78          17
# 3        Margate  51.3813    1.3862     55.31        74          11
# 4          Kapaa  22.0752 -159.3190     78.78        87          75
# 5        Rikitea -23.1203 -134.9692     74.77        82          96
# 6    Tuktoyaktuk  69.4541 -133.0374     28.40        93          75
# 7        Lerwick  60.1545   -1.1494     51.80        89         100
# 8        Ushuaia -54.8000  -68.3000     35.26        93          75
# 9      Coihaique -45.5752  -72.0662     54.21        40          20
#
#    Wind Speed Country Current Description
# 0       18.41      CA    scattered clouds
# 1        5.86      IR           clear sky
# 2        2.06      GR          few clouds
# 3       14.27      GB          few clouds
# 4       12.66      US       broken clouds
# 5       20.58      PF     overcast clouds
# 6        9.22      CA       broken clouds
# 7       25.75      GB     overcast clouds
# 8       28.77      AR          light snow
# 9       16.11      CL          few clouds

# %%
#Create the ouput file (CSV)
output_data_file="Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file,index_label="City_ID")
