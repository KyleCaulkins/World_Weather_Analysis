# %%
#Import dependencies and setup citipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats=np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs=np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates=list(lat_lngs)

# %%
#Create a list for holding the cities
cities=[]
#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)
#Print the city count
len(cities)
# Out:
# 771

# %%
#Perform an API call with the OpenWeatherMap
#Import requests library
import requests
#Import the API key
from config import weather_api_key

# %%
#Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data=[]

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count=1
set_count=1

#Loop through all cities in the list
for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes
    if (i % 50==0 and i >= 50):
        set_count += 1
        record_count =1
    #Create enpoint URL with each city
    city_url=url+"&q="+city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count +=1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | lorengau
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | tuatapere
# Processing Record 5 of Set 1 | kalino
# Processing Record 6 of Set 1 | harper
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | sobolevo
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | barreirinha
# Processing Record 13 of Set 1 | guerrero negro
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | akyab
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | chicama
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | salalah
# Processing Record 22 of Set 1 | bolu
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | codrington
# Processing Record 25 of Set 1 | setermoen
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | norwich
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | chernyshevskiy
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | chinsali
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | praia da vitoria
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | sorong
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | tiksi
# Processing Record 42 of Set 1 | san quintin
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | lasa
# Processing Record 45 of Set 1 | charlestown
# Processing Record 46 of Set 1 | kamphaeng phet
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | san borja
# Processing Record 49 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 1 | abu dhabi
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | minab
# Processing Record 3 of Set 2 | svetlogorsk
# Processing Record 4 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | mehamn
# Processing Record 8 of Set 2 | punta alta
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | iranshahr
# Processing Record 11 of Set 2 | provideniya
# Processing Record 12 of Set 2 | santa cruz
# Processing Record 13 of Set 2 | esperance
# Processing Record 14 of Set 2 | troitskoye
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | tual
# Processing Record 17 of Set 2 | bentiu
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | chiquilistlan
# Processing Record 22 of Set 2 | inta
# Processing Record 23 of Set 2 | batemans bay
# Processing Record 24 of Set 2 | zarubino
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | husavik
# Processing Record 28 of Set 2 | pisco
# Processing Record 29 of Set 2 | hay river
# Processing Record 30 of Set 2 | busselton
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | upernavik
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | bang saphan
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | mossendjo
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | iquique
# Processing Record 39 of Set 2 | camabatela
# Processing Record 40 of Set 2 | sorland
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | college
# Processing Record 43 of Set 2 | verkhnevilyuysk
# Processing Record 44 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 2 | kalmunai
# Processing Record 46 of Set 2 | kirakira
# Processing Record 47 of Set 2 | ilulissat
# Processing Record 48 of Set 2 | batagay-alyta
# Processing Record 49 of Set 2 | quang ngai
# Processing Record 50 of Set 2 | moose factory
# Processing Record 1 of Set 3 | carutapera
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | kashi
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | timra
# Processing Record 6 of Set 3 | boyabat
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | goderich
# Processing Record 9 of Set 3 | laguna
# Processing Record 10 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 3 | nome
# Processing Record 12 of Set 3 | lata
# Processing Record 13 of Set 3 | doba
# Processing Record 14 of Set 3 | whitehorse
# Processing Record 15 of Set 3 | manuk mangkaw
# Processing Record 16 of Set 3 | kapaa
# Processing Record 17 of Set 3 | jalu
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | richards bay
# Processing Record 21 of Set 3 | dickinson
# Processing Record 22 of Set 3 | naze
# Processing Record 23 of Set 3 | dingle
# Processing Record 24 of Set 3 | boralday
# Processing Record 25 of Set 3 | roebourne
# Processing Record 26 of Set 3 | katrineholm
# Processing Record 27 of Set 3 | kavieng
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | pirmasens
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | thinadhoo
# Processing Record 33 of Set 3 | mahibadhoo
# Processing Record 34 of Set 3 | nishihara
# Processing Record 35 of Set 3 | umba
# Processing Record 36 of Set 3 | chaihe
# Processing Record 37 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 3 | tir pol
# City not found. Skipping...
# Processing Record 39 of Set 3 | dombas
# Processing Record 40 of Set 3 | mount isa
# Processing Record 41 of Set 3 | kasamwa
# Processing Record 42 of Set 3 | mahebourg
# Processing Record 43 of Set 3 | olafsvik
# Processing Record 44 of Set 3 | charters towers
# Processing Record 45 of Set 3 | souillac
# Processing Record 46 of Set 3 | maceio
# Processing Record 47 of Set 3 | saint george
# Processing Record 48 of Set 3 | tazovskiy
# Processing Record 49 of Set 3 | port blair
# Processing Record 50 of Set 3 | panacan
# Processing Record 1 of Set 4 | belyy yar
# Processing Record 2 of Set 4 | puerto escondido
# Processing Record 3 of Set 4 | surab
# Processing Record 4 of Set 4 | puerto baquerizo moreno
# Processing Record 5 of Set 4 | stornoway
# Processing Record 6 of Set 4 | maracacume
# Processing Record 7 of Set 4 | hermanus
# Processing Record 8 of Set 4 | mount gambier
# Processing Record 9 of Set 4 | flin flon
# Processing Record 10 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 4 | dajal
# Processing Record 12 of Set 4 | tecoanapa
# Processing Record 13 of Set 4 | severo-kurilsk
# Processing Record 14 of Set 4 | santiago del estero
# Processing Record 15 of Set 4 | ouegoa
# Processing Record 16 of Set 4 | la ronge
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | leshukonskoye
# Processing Record 19 of Set 4 | anloga
# Processing Record 20 of Set 4 | nyagan
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | sambava
# Processing Record 23 of Set 4 | kodiak
# Processing Record 24 of Set 4 | diego de almagro
# Processing Record 25 of Set 4 | homer
# Processing Record 26 of Set 4 | miandrivazo
# Processing Record 27 of Set 4 | lodingen
# Processing Record 28 of Set 4 | anupgarh
# Processing Record 29 of Set 4 | bonfim
# Processing Record 30 of Set 4 | cape town
# Processing Record 31 of Set 4 | bondeno
# Processing Record 32 of Set 4 | adrar
# Processing Record 33 of Set 4 | chadiza
# Processing Record 34 of Set 4 | sainte-anne-des-monts
# Processing Record 35 of Set 4 | fairbanks
# Processing Record 36 of Set 4 | itupiranga
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | bandarbeyla
# Processing Record 39 of Set 4 | kudahuvadhoo
# Processing Record 40 of Set 4 | rio cuarto
# Processing Record 41 of Set 4 | sal rei
# Processing Record 42 of Set 4 | arman
# Processing Record 43 of Set 4 | cherskiy
# Processing Record 44 of Set 4 | mantua
# Processing Record 45 of Set 4 | mar del plata
# Processing Record 46 of Set 4 | tendukheda
# Processing Record 47 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 4 | touros
# Processing Record 49 of Set 4 | ushtobe
# Processing Record 50 of Set 4 | butaritari
# Processing Record 1 of Set 5 | puerto barrios
# Processing Record 2 of Set 5 | konza
# Processing Record 3 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 5 | bure
# Processing Record 5 of Set 5 | llanes
# Processing Record 6 of Set 5 | namibe
# Processing Record 7 of Set 5 | alta floresta
# Processing Record 8 of Set 5 | klaksvik
# Processing Record 9 of Set 5 | fortuna
# Processing Record 10 of Set 5 | sept-iles
# Processing Record 11 of Set 5 | ambulu
# Processing Record 12 of Set 5 | sao joao da barra
# Processing Record 13 of Set 5 | havoysund
# Processing Record 14 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 5 | te anau
# Processing Record 16 of Set 5 | kasempa
# Processing Record 17 of Set 5 | bulgan
# Processing Record 18 of Set 5 | pacific grove
# Processing Record 19 of Set 5 | presidencia roque saenz pena
# Processing Record 20 of Set 5 | mogadishu
# Processing Record 21 of Set 5 | milkovo
# Processing Record 22 of Set 5 | iqaluit
# Processing Record 23 of Set 5 | winslow
# Processing Record 24 of Set 5 | yerbogachen
# Processing Record 25 of Set 5 | baoma
# Processing Record 26 of Set 5 | barra patuca
# Processing Record 27 of Set 5 | georgetown
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 30 of Set 5 | krasnoselkup
# Processing Record 31 of Set 5 | newport
# Processing Record 32 of Set 5 | sao filipe
# Processing Record 33 of Set 5 | hella
# Processing Record 34 of Set 5 | saskylakh
# Processing Record 35 of Set 5 | ipixuna
# Processing Record 36 of Set 5 | cockburn town
# Processing Record 37 of Set 5 | mayumba
# Processing Record 38 of Set 5 | les cayes
# Processing Record 39 of Set 5 | crato
# Processing Record 40 of Set 5 | conde
# Processing Record 41 of Set 5 | cayenne
# Processing Record 42 of Set 5 | avarua
# Processing Record 43 of Set 5 | loralai
# Processing Record 44 of Set 5 | luderitz
# Processing Record 45 of Set 5 | teya
# Processing Record 46 of Set 5 | karratha
# Processing Record 47 of Set 5 | half moon bay
# Processing Record 48 of Set 5 | port hedland
# Processing Record 49 of Set 5 | nalut
# Processing Record 50 of Set 5 | keningau
# Processing Record 1 of Set 6 | pasni
# Processing Record 2 of Set 6 | bunia
# Processing Record 3 of Set 6 | burnie
# Processing Record 4 of Set 6 | barrow
# Processing Record 5 of Set 6 | gat
# Processing Record 6 of Set 6 | taree
# Processing Record 7 of Set 6 | lagoa
# Processing Record 8 of Set 6 | shitanjing
# Processing Record 9 of Set 6 | simpang
# Processing Record 10 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 6 | caravelas
# Processing Record 12 of Set 6 | conceicao da barra
# Processing Record 13 of Set 6 | acarau
# Processing Record 14 of Set 6 | port keats
# Processing Record 15 of Set 6 | dunedin
# Processing Record 16 of Set 6 | launceston
# Processing Record 17 of Set 6 | suzun
# Processing Record 18 of Set 6 | sayyan
# Processing Record 19 of Set 6 | goundam
# Processing Record 20 of Set 6 | yumen
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | guaymango
# Processing Record 23 of Set 6 | yarmouth
# Processing Record 24 of Set 6 | monrovia
# Processing Record 25 of Set 6 | mortka
# Processing Record 26 of Set 6 | ola
# Processing Record 27 of Set 6 | lufilufi
# Processing Record 28 of Set 6 | urucara
# Processing Record 29 of Set 6 | namtsy
# Processing Record 30 of Set 6 | guadalupe
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | jinxiang
# Processing Record 33 of Set 6 | nazare
# Processing Record 34 of Set 6 | cabedelo
# Processing Record 35 of Set 6 | upington
# Processing Record 36 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 6 | phan thiet
# Processing Record 40 of Set 6 | kawalu
# Processing Record 41 of Set 6 | riviere-au-renard
# Processing Record 42 of Set 6 | paita
# Processing Record 43 of Set 6 | coihaique
# Processing Record 44 of Set 6 | ukiah
# Processing Record 45 of Set 6 | nhulunbuy
# Processing Record 46 of Set 6 | katsuura
# Processing Record 47 of Set 6 | port lincoln
# Processing Record 48 of Set 6 | westerland
# Processing Record 49 of Set 6 | ahipara
# Processing Record 50 of Set 6 | karangasem
# Processing Record 1 of Set 7 | el pueblito
# Processing Record 2 of Set 7 | banda aceh
# Processing Record 3 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 7 | wasilla
# Processing Record 5 of Set 7 | soyo
# Processing Record 6 of Set 7 | sao felix do xingu
# Processing Record 7 of Set 7 | san rafael del sur
# Processing Record 8 of Set 7 | sao goncalo do amarante
# Processing Record 9 of Set 7 | sawtell
# Processing Record 10 of Set 7 | tanda
# Processing Record 11 of Set 7 | hohhot
# Processing Record 12 of Set 7 | santa rosa
# Processing Record 13 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 7 | port hardy
# Processing Record 15 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 7 | tromso
# Processing Record 17 of Set 7 | okhotsk
# Processing Record 18 of Set 7 | celestun
# Processing Record 19 of Set 7 | sembabule
# Processing Record 20 of Set 7 | henderson
# Processing Record 21 of Set 7 | bluefields
# Processing Record 22 of Set 7 | vostok
# Processing Record 23 of Set 7 | cabra
# Processing Record 24 of Set 7 | havre-saint-pierre
# Processing Record 25 of Set 7 | phalaborwa
# Processing Record 26 of Set 7 | barbate
# Processing Record 27 of Set 7 | bahir dar
# Processing Record 28 of Set 7 | kruisfontein
# Processing Record 29 of Set 7 | north bend
# Processing Record 30 of Set 7 | nouadhibou
# Processing Record 31 of Set 7 | tura
# Processing Record 32 of Set 7 | mtambile
# Processing Record 33 of Set 7 | vryburg
# Processing Record 34 of Set 7 | teahupoo
# Processing Record 35 of Set 7 | igarka
# Processing Record 36 of Set 7 | comrat
# Processing Record 37 of Set 7 | taoudenni
# Processing Record 38 of Set 7 | jieshi
# Processing Record 39 of Set 7 | almaznyy
# Processing Record 40 of Set 7 | mogapinyana
# Processing Record 41 of Set 7 | bethel
# Processing Record 42 of Set 7 | arlit
# Processing Record 43 of Set 7 | tilichiki
# Processing Record 44 of Set 7 | piacabucu
# Processing Record 45 of Set 7 | kieta
# Processing Record 46 of Set 7 | lazaro cardenas
# Processing Record 47 of Set 7 | cidreira
# Processing Record 48 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 7 | ormara
# Processing Record 50 of Set 7 | narasannapeta
# Processing Record 1 of Set 8 | bubaque
# Processing Record 2 of Set 8 | sargatskoye
# Processing Record 3 of Set 8 | saldanha
# Processing Record 4 of Set 8 | xifeng
# Processing Record 5 of Set 8 | linxia
# Processing Record 6 of Set 8 | omboue
# Processing Record 7 of Set 8 | conceicao do araguaia
# Processing Record 8 of Set 8 | mattru
# Processing Record 9 of Set 8 | maridi
# Processing Record 10 of Set 8 | jibuti
# Processing Record 11 of Set 8 | makakilo city
# Processing Record 12 of Set 8 | hastings
# Processing Record 13 of Set 8 | pascagoula
# Processing Record 14 of Set 8 | buala
# Processing Record 15 of Set 8 | marsa matruh
# Processing Record 16 of Set 8 | ilhabela
# Processing Record 17 of Set 8 | dharchula
# Processing Record 18 of Set 8 | yankton
# Processing Record 19 of Set 8 | denpasar
# Processing Record 20 of Set 8 | marsh harbour
# Processing Record 21 of Set 8 | luau
# Processing Record 22 of Set 8 | deputatskiy
# Processing Record 23 of Set 8 | merrill
# Processing Record 24 of Set 8 | jasper
# Processing Record 25 of Set 8 | faanui
# Processing Record 26 of Set 8 | loikaw
# Processing Record 27 of Set 8 | grand gaube
# Processing Record 28 of Set 8 | mareeba
# Processing Record 29 of Set 8 | tebingtinggi
# Processing Record 30 of Set 8 | trelew
# Processing Record 31 of Set 8 | tasiilaq
# Processing Record 32 of Set 8 | nadapuram
# Processing Record 33 of Set 8 | wanning
# Processing Record 34 of Set 8 | risch
# Processing Record 35 of Set 8 | pericos
# Processing Record 36 of Set 8 | sao francisco
# Processing Record 37 of Set 8 | biltine
# Processing Record 38 of Set 8 | sur
# Processing Record 39 of Set 8 | ugoofaaru
# Processing Record 40 of Set 8 | huarmey
# Processing Record 41 of Set 8 | malakal
# Processing Record 42 of Set 8 | ust-ishim
# Processing Record 43 of Set 8 | umm kaddadah
# Processing Record 44 of Set 8 | kenora
# Processing Record 45 of Set 8 | alyangula
# Processing Record 46 of Set 8 | tungor
# Processing Record 47 of Set 8 | kita
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | masuguru
# Processing Record 50 of Set 8 | tsogni
# Processing Record 1 of Set 9 | vilhena
# Processing Record 2 of Set 9 | tamandare
# Processing Record 3 of Set 9 | ancud
# Processing Record 4 of Set 9 | tolaga bay
# Processing Record 5 of Set 9 | priekule
# Processing Record 6 of Set 9 | maarianhamina
# Processing Record 7 of Set 9 | porto novo
# Processing Record 8 of Set 9 | talnakh
# Processing Record 9 of Set 9 | maningrida
# Processing Record 10 of Set 9 | vao
# Processing Record 11 of Set 9 | merano
# Processing Record 12 of Set 9 | byron bay
# Processing Record 13 of Set 9 | catamarca
# Processing Record 14 of Set 9 | madang
# Processing Record 15 of Set 9 | kathmandu
# Processing Record 16 of Set 9 | baruun-urt
# Processing Record 17 of Set 9 | pevek
# Processing Record 18 of Set 9 | poronaysk
# Processing Record 19 of Set 9 | mukhen
# Processing Record 20 of Set 9 | poum
# Processing Record 21 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 22 of Set 9 | doha
# Processing Record 23 of Set 9 | karasburg
# Processing Record 24 of Set 9 | mpika
# Processing Record 25 of Set 9 | pilar
# Processing Record 26 of Set 9 | iztapa
# Processing Record 27 of Set 9 | znamenskoye
# Processing Record 28 of Set 9 | port macquarie
# Processing Record 29 of Set 9 | sioni
# Processing Record 30 of Set 9 | teguldet
# Processing Record 31 of Set 9 | aklavik
# Processing Record 32 of Set 9 | rawson
# Processing Record 33 of Set 9 | champerico
# Processing Record 34 of Set 9 | anchorage
# Processing Record 35 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 9 | iraquara
# Processing Record 37 of Set 9 | ughelli
# Processing Record 38 of Set 9 | santiago de chuco
# Processing Record 39 of Set 9 | nago
# Processing Record 40 of Set 9 | marawi
# Processing Record 41 of Set 9 | blythe
# Processing Record 42 of Set 9 | talcahuano
# Processing Record 43 of Set 9 | barabai
# Processing Record 44 of Set 9 | mao
# Processing Record 45 of Set 9 | lillooet
# Processing Record 46 of Set 9 | hervey bay
# Processing Record 47 of Set 9 | hirson
# Processing Record 48 of Set 9 | los llanos de aridane
# Processing Record 49 of Set 9 | daru
# Processing Record 50 of Set 9 | broken hill
# Processing Record 1 of Set 10 | uryupinsk
# Processing Record 2 of Set 10 | gitega
# Processing Record 3 of Set 10 | trairi
# Processing Record 4 of Set 10 | weligama
# Processing Record 5 of Set 10 | morant bay
# Processing Record 6 of Set 10 | tigil
# Processing Record 7 of Set 10 | araguacu
# Processing Record 8 of Set 10 | skara
# Processing Record 9 of Set 10 | qasigiannguit
# Processing Record 10 of Set 10 | kovur
# Processing Record 11 of Set 10 | cap malheureux
# Processing Record 12 of Set 10 | skeldon
# Processing Record 13 of Set 10 | bow island
# Processing Record 14 of Set 10 | coquimbo
# Processing Record 15 of Set 10 | ussuriysk
# Processing Record 16 of Set 10 | tessalit
# Processing Record 17 of Set 10 | taiyuan
# Processing Record 18 of Set 10 | greymouth
# Processing Record 19 of Set 10 | marau
# Processing Record 20 of Set 10 | asau
# Processing Record 21 of Set 10 | muisne
# Processing Record 22 of Set 10 | san cristobal
# Processing Record 23 of Set 10 | san andres
# Processing Record 24 of Set 10 | korla
# Processing Record 25 of Set 10 | san felipe
# Processing Record 26 of Set 10 | lavrentiya
# Processing Record 27 of Set 10 | traiguen
# Processing Record 28 of Set 10 | sarai naurang
# Processing Record 29 of Set 10 | plettenberg bay
# Processing Record 30 of Set 10 | funtua
# Processing Record 31 of Set 10 | birao
# Processing Record 32 of Set 10 | nelson bay
# Processing Record 33 of Set 10 | bilma
# Processing Record 34 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 36 of Set 10 | kurilsk
# Processing Record 37 of Set 10 | padang
# Processing Record 38 of Set 10 | bingol
# Processing Record 39 of Set 10 | sao desiderio
# Processing Record 40 of Set 10 | belaya gora
# Processing Record 41 of Set 10 | itarema
# Processing Record 42 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 10 | yaan
# Processing Record 44 of Set 10 | oranjemund
# Processing Record 45 of Set 10 | camacha
# Processing Record 46 of Set 10 | chimoio
# Processing Record 47 of Set 10 | tautira
# Processing Record 48 of Set 10 | esso
# Processing Record 49 of Set 10 | kaitangata
# Processing Record 50 of Set 10 | pringsewu
# Processing Record 1 of Set 11 | barcelos
# Processing Record 2 of Set 11 | sangar
# Processing Record 3 of Set 11 | dipkarpaz
# City not found. Skipping...
# Processing Record 4 of Set 11 | dong hoi
# Processing Record 5 of Set 11 | along
# Processing Record 6 of Set 11 | ravar
# Processing Record 7 of Set 11 | praia
# Processing Record 8 of Set 11 | vila velha
# Processing Record 9 of Set 11 | zhigalovo
# Processing Record 10 of Set 11 | sikonge
# Processing Record 11 of Set 11 | albufeira
# Processing Record 12 of Set 11 | geraldton
# Processing Record 13 of Set 11 | vestmannaeyjar
# Processing Record 14 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 11 | comodoro rivadavia
# Processing Record 16 of Set 11 | lindome
# Processing Record 17 of Set 11 | tadine
# Processing Record 18 of Set 11 | kapit
# Processing Record 19 of Set 11 | molochnoye
# Processing Record 20 of Set 11 | pochutla
# Processing Record 21 of Set 11 | taraz
# Processing Record 22 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 11 | barabinsk
# Processing Record 24 of Set 11 | beringovskiy
# Processing Record 25 of Set 11 | kangaatsiaq
# Processing Record 26 of Set 11 | orsha
# Processing Record 27 of Set 11 | dhidhdhoo
# Processing Record 28 of Set 11 | kahului
# Processing Record 29 of Set 11 | neuquen
# Processing Record 30 of Set 11 | voh
# Processing Record 31 of Set 11 | saint-pierre
# Processing Record 32 of Set 11 | nerekhta
# Processing Record 33 of Set 11 | peterhead
# Processing Record 34 of Set 11 | kenai
# Processing Record 35 of Set 11 | george town
# Processing Record 36 of Set 11 | juneau
# Processing Record 37 of Set 11 | nanortalik
# Processing Record 38 of Set 11 | constitucion
# Processing Record 39 of Set 11 | yialos
# City not found. Skipping...
# Processing Record 40 of Set 11 | rabo de peixe
# Processing Record 41 of Set 11 | tiruchchendur
# Processing Record 42 of Set 11 | yuci
# Processing Record 43 of Set 11 | isparta
# Processing Record 44 of Set 11 | narrabri
# Processing Record 45 of Set 11 | chauk
# Processing Record 46 of Set 11 | tombouctou
# Processing Record 47 of Set 11 | vuktyl
# Processing Record 48 of Set 11 | fort nelson
# Processing Record 49 of Set 11 | ans
# Processing Record 50 of Set 11 | vanavara
# Processing Record 1 of Set 12 | yei
# Processing Record 2 of Set 12 | lang son
# Processing Record 3 of Set 12 | terrace bay
# Processing Record 4 of Set 12 | ofaqim
# Processing Record 5 of Set 12 | chartres
# Processing Record 6 of Set 12 | narsaq
# Processing Record 7 of Set 12 | rock sound
# Processing Record 8 of Set 12 | elvas
# Processing Record 9 of Set 12 | orocue
# Processing Record 10 of Set 12 | iroquois falls
# Processing Record 11 of Set 12 | mandera
# Processing Record 12 of Set 12 | belo horizonte
# Processing Record 13 of Set 12 | aswan
# Processing Record 14 of Set 12 | aliwal north
# Processing Record 15 of Set 12 | ramnicelu
# Processing Record 16 of Set 12 | kattivakkam
# Processing Record 17 of Set 12 | ibotirama
# Processing Record 18 of Set 12 | saskatoon
# Processing Record 19 of Set 12 | yar-sale
# Processing Record 20 of Set 12 | astipalaia
# City not found. Skipping...
# Processing Record 21 of Set 12 | acapulco
# Processing Record 22 of Set 12 | sofia
# Processing Record 23 of Set 12 | rutana
# Processing Record 24 of Set 12 | rio grande
# Processing Record 25 of Set 12 | jacqueville
# Processing Record 26 of Set 12 | tagusao
# Processing Record 27 of Set 12 | progreso
# Processing Record 28 of Set 12 | inhambane
# Processing Record 29 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 12 | macau
# Processing Record 31 of Set 12 | tezu
# Processing Record 32 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 33 of Set 12 | gornozavodsk
# Processing Record 34 of Set 12 | watsa
# Processing Record 35 of Set 12 | roald
# Processing Record 36 of Set 12 | saint-ambroise
# Processing Record 37 of Set 12 | eureka
# Processing Record 38 of Set 12 | mackay
# Processing Record 39 of Set 12 | atasu
# Processing Record 40 of Set 12 | petawawa
# Processing Record 41 of Set 12 | makushino
# Processing Record 42 of Set 12 | paraiso
# Processing Record 43 of Set 12 | pokrovskoye
# Processing Record 44 of Set 12 | babu
# Processing Record 45 of Set 12 | meulaboh
# Processing Record 46 of Set 12 | nyurba
# Processing Record 47 of Set 12 | jumla
# Processing Record 48 of Set 12 | komsomolskiy
# Processing Record 49 of Set 12 | pandan niog
# Processing Record 50 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 13 | el rusio
# Processing Record 2 of Set 13 | maragogi
# Processing Record 3 of Set 13 | cascais
# Processing Record 4 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 5 of Set 13 | oistins
# Processing Record 6 of Set 13 | nabire
# Processing Record 7 of Set 13 | ambilobe
# Processing Record 8 of Set 13 | stolin
# Processing Record 9 of Set 13 | nosy varika
# Processing Record 10 of Set 13 | saint-paul
# Processing Record 11 of Set 13 | san ignacio
# Processing Record 12 of Set 13 | the valley
# Processing Record 13 of Set 13 | bereda
# Processing Record 14 of Set 13 | winnemucca
# Processing Record 15 of Set 13 | xiamen
# Processing Record 16 of Set 13 | pangnirtung
# Processing Record 17 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 13 | grenville
# Processing Record 19 of Set 13 | aksu
# Processing Record 20 of Set 13 | vila do maio
# Processing Record 21 of Set 13 | eyl
# Processing Record 22 of Set 13 | ostersund
# Processing Record 23 of Set 13 | pinega
# Processing Record 24 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 13 | gornyak
# Processing Record 26 of Set 13 | bertoua
# Processing Record 27 of Set 13 | asfi
# Processing Record 28 of Set 13 | kingman
# Processing Record 29 of Set 13 | kiri buru
# Processing Record 30 of Set 13 | port-cartier
# Processing Record 31 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 32 of Set 13 | pokosnoye
# Processing Record 33 of Set 13 | saint-augustin
# Processing Record 34 of Set 13 | lephepe
# City not found. Skipping...
# Processing Record 35 of Set 13 | ostrovnoy
# Processing Record 36 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 37 of Set 13 | butiama
# Processing Record 38 of Set 13 | najran
# Processing Record 39 of Set 13 | bowen
# Processing Record 40 of Set 13 | lakefield
# Processing Record 41 of Set 13 | lardos
# Processing Record 42 of Set 13 | anadyr
# Processing Record 43 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 13 | harer
# Processing Record 45 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 13 | cardston
# Processing Record 47 of Set 13 | avera
# Processing Record 48 of Set 13 | srandakan
# Processing Record 49 of Set 13 | acajutla
# Processing Record 50 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 1 of Set 14 | tortel
# Processing Record 2 of Set 14 | otjimbingwe
# Processing Record 3 of Set 14 | prince rupert
# Processing Record 4 of Set 14 | majene
# Processing Record 5 of Set 14 | tarko-sale
# Processing Record 6 of Set 14 | borba
# Processing Record 7 of Set 14 | evensk
# Processing Record 8 of Set 14 | raudeberg
# Processing Record 9 of Set 14 | mbaiki
# Processing Record 10 of Set 14 | alice springs
# Processing Record 11 of Set 14 | menongue
# Processing Record 12 of Set 14 | castanos
# Processing Record 13 of Set 14 | bafra
# Processing Record 14 of Set 14 | shakawe
# Processing Record 15 of Set 14 | ziyang
# Processing Record 16 of Set 14 | mayo
# Processing Record 17 of Set 14 | mengyin
# Processing Record 18 of Set 14 | giresun
# Processing Record 19 of Set 14 | baripada
# Processing Record 20 of Set 14 | hobyo
# Processing Record 21 of Set 14 | bosaso
# Processing Record 22 of Set 14 | toulepleu
# City not found. Skipping...
# Processing Record 23 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 14 | lompoc
# Processing Record 25 of Set 14 | mitu
# Processing Record 26 of Set 14 | ishigaki
# Processing Record 27 of Set 14 | belmonte
# Processing Record 28 of Set 14 | neiafu
# Processing Record 29 of Set 14 | pangoa
# Processing Record 30 of Set 14 | jabinyanah
# Processing Record 31 of Set 14 | caconda
# Processing Record 32 of Set 14 | namatanai
# Processing Record 33 of Set 14 | sunamganj
# City not found. Skipping...
# Processing Record 34 of Set 14 | stokmarknes
# Processing Record 35 of Set 14 | amapa
# Processing Record 36 of Set 14 | palu
# Processing Record 37 of Set 14 | haines junction
# Processing Record 38 of Set 14 | gornopravdinsk
# Processing Record 39 of Set 14 | urumqi
# Processing Record 40 of Set 14 | porto santo
# Processing Record 41 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 42 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 14 | safaga
# Processing Record 44 of Set 14 | lagos
# Processing Record 45 of Set 14 | alofi
# Processing Record 46 of Set 14 | yaring
# Processing Record 47 of Set 14 | khandagayty
# Processing Record 48 of Set 14 | takoradi
# Processing Record 49 of Set 14 | port-gentil
# Processing Record 50 of Set 14 | vardo
# Processing Record 1 of Set 15 | goya
# Processing Record 2 of Set 15 | severo-yeniseyskiy
# Processing Record 3 of Set 15 | aksay
# Processing Record 4 of Set 15 | tonantins
# Processing Record 5 of Set 15 | angol
# Processing Record 6 of Set 15 | sibu
# Processing Record 7 of Set 15 | kutum
# Processing Record 8 of Set 15 | la marque
# Processing Record 9 of Set 15 | cravo norte
# Processing Record 10 of Set 15 | jinchengjiang
# City not found. Skipping...
# Processing Record 11 of Set 15 | oussouye
# Processing Record 12 of Set 15 | safford
# Processing Record 13 of Set 15 | altamira
# Processing Record 14 of Set 15 | moree
# Processing Record 15 of Set 15 | sanming
# Processing Record 16 of Set 15 | hovd
# Processing Record 17 of Set 15 | san carlos de bariloche
# Processing Record 18 of Set 15 | yulara
# Processing Record 19 of Set 15 | tyler
# Processing Record 20 of Set 15 | muddebihal
# Processing Record 21 of Set 15 | ankazoabo
# Processing Record 22 of Set 15 | todos santos
# Processing Record 23 of Set 15 | oxford
# Processing Record 24 of Set 15 | zalantun
# Processing Record 25 of Set 15 | seoul
# Processing Record 26 of Set 15 | miles city
# Processing Record 27 of Set 15 | portland
# Processing Record 28 of Set 15 | sechura
# Processing Record 29 of Set 15 | sawakin
# Processing Record 30 of Set 15 | terenga
# City not found. Skipping...
# Processing Record 31 of Set 15 | san policarpo
# Processing Record 32 of Set 15 | puerto ayacucho
# Processing Record 33 of Set 15 | mabaruma
# Processing Record 34 of Set 15 | necochea
# Processing Record 35 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 15 | slantsy
# Processing Record 37 of Set 15 | labuhan
# Processing Record 38 of Set 15 | bharatpur
# Processing Record 39 of Set 15 | port augusta
# Processing Record 40 of Set 15 | kargopol
# Processing Record 41 of Set 15 | moindou
# Processing Record 42 of Set 15 | lithakia
# Processing Record 43 of Set 15 | hailar
# Processing Record 44 of Set 15 | mazamari
# Processing Record 45 of Set 15 | green valley
# Processing Record 46 of Set 15 | bundaberg
# Processing Record 47 of Set 15 | abapo
# Processing Record 48 of Set 15 | george
# Processing Record 49 of Set 15 | tawang
# Processing Record 50 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 1 of Set 16 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 16 | langsa
# Processing Record 3 of Set 16 | amazar
# Processing Record 4 of Set 16 | canon city
# Processing Record 5 of Set 16 | bangkalan
# Processing Record 6 of Set 16 | araouane
# Processing Record 7 of Set 16 | purpe
# Processing Record 8 of Set 16 | diffa
# Processing Record 9 of Set 16 | atambua
# Processing Record 10 of Set 16 | virden
# Processing Record 11 of Set 16 | hualmay
# Processing Record 12 of Set 16 | udaipura
# Processing Record 13 of Set 16 | honiara
# Processing Record 14 of Set 16 | baykit
# Processing Record 15 of Set 16 | topalu
# Processing Record 16 of Set 16 | aykhal
# Processing Record 17 of Set 16 | thenzawl
# Processing Record 18 of Set 16 | makung
# City not found. Skipping...
# Processing Record 19 of Set 16 | verkhoyansk
# Processing Record 20 of Set 16 | sola
# Processing Record 21 of Set 16 | surt
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a pandas dataframe
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Lebu -37.6167  -73.6500     54.73        69          27        9.46
# 1   Lorengau  -2.0226  147.2712     80.65        82          43        9.48
# 2    Rikitea -23.1203 -134.9692     74.77        82          96       20.58
# 3  Tuatapere -46.1333  167.6833     50.86        96         100        1.54
# 4     Kalino  58.2504   57.6085     41.95        84         100        8.66
# 5     Harper   4.3750   -7.7169     77.68        88          79        7.72
# 6      Vaini -21.2000 -175.2000     71.53        72          78       22.62
# 7   Bengkulu  -3.8004  102.2655     76.21        89          80        2.89
# 8   Sobolevo  54.4299   31.8996     41.83        68          97       15.95
# 9    Mataura -46.1927  168.8643     49.48        97         100        0.40
#
#   Country Current Description
# 0      CL    scattered clouds
# 1      PG    scattered clouds
# 2      PF     overcast clouds
# 3      NZ     overcast clouds
# 4      RU     overcast clouds
# 5      LR          light rain
# 6      TO          light rain
# 7      ID       broken clouds
# 8      RU     overcast clouds
# 9      NZ          light rain

# %%
#New column order to match Challenge given image
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Lebu      CL -37.6167  -73.6500     54.73        69          27
# 1   Lorengau      PG  -2.0226  147.2712     80.65        82          43
# 2    Rikitea      PF -23.1203 -134.9692     74.77        82          96
# 3  Tuatapere      NZ -46.1333  167.6833     50.86        96         100
# 4     Kalino      RU  58.2504   57.6085     41.95        84         100
#
#    Wind Speed Current Description
# 0        9.46    scattered clouds
# 1        9.48    scattered clouds
# 2       20.58     overcast clouds
# 3        1.54     overcast clouds
# 4        8.66     overcast clouds

# %%
#Create the ouput file (CSV)
output_data_file="Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file,index_label="City_ID")
